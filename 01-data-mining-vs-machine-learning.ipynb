# %% [markdown]
# # Exercise 1 — Data Mining vs Machine Learning

# %% [markdown]
# What you will learn here:
#
# * distinguish data vs labels
# * think about problem formulation
# * connect real data → ML type
# * understand when ML is needed

# %%
# If needed:
# !pip install datasets pandas matplotlib scikit-learn librosa

# %%
from datasets import load_dataset
import pandas as pd

# %% [markdown]
# Load a small sample from the `ag_news` dataset and is a collection of more than 1 million news articles.

# %%
dataset = load_dataset("ag_news", split="train[:200]")

df = dataset.to_pandas()
df.head()
# Out:
#                                                 text  label
# 0  Wall St. Bears Claw Back Into the Black (Reute...      2
# 1  Carlyle Looks Toward Commercial Aerospace (Reu...      2
# 2  Oil and Economy Cloud Stocks' Outlook (Reuters...      2
# 3  Iraq Halts Oil Exports from Main Southern Pipe...      2
# 4  Oil prices soar to all-time record, posing new...      2

# %% [markdown]
# ### Understand the dataset

# %%
df.columns
# Out:
# Index(['text', 'label'], dtype='object')

# %%
df[["text", "label"]].head(10)
# Out:
#                                                 text  label
# 0  Wall St. Bears Claw Back Into the Black (Reute...      2
# 1  Carlyle Looks Toward Commercial Aerospace (Reu...      2
# 2  Oil and Economy Cloud Stocks' Outlook (Reuters...      2
# 3  Iraq Halts Oil Exports from Main Southern Pipe...      2
# 4  Oil prices soar to all-time record, posing new...      2
# 5  Stocks End Up, But Near Year Lows (Reuters) Re...      2
# 6  Money Funds Fell in Latest Week (AP) AP - Asse...      2
# 7  Fed minutes show dissent over inflation (USATO...      2
# 8  Safety Net (Forbes.com) Forbes.com - After ear...      2
# 9  Wall St. Bears Claw Back Into the Black  NEW Y...      2

# %% [markdown]
# ## Question
# What are the columns?
#
# - Which column is the input data?
# - Which column is the label?

# %% [markdown]
# - Column to input data is text
# - Column is the label is label

# %% [markdown]
# # Part A — Data Mining: Discover patterns

# %% [markdown]
# For this step, you cannot use the `label` column. :)

# %% [markdown]
# ### Text length

# %%
df["text_length"] = df["text"].apply(len)

df[["text", "text_length"]].head()
# Out:
#                                                 text  text_length
# 0  Wall St. Bears Claw Back Into the Black (Reute...          144
# 1  Carlyle Looks Toward Commercial Aerospace (Reu...          266
# 2  Oil and Economy Cloud Stocks' Outlook (Reuters...          232
# 3  Iraq Halts Oil Exports from Main Southern Pipe...          256
# 4  Oil prices soar to all-time record, posing new...          234

# %% [markdown]
# ### Average text length

# %%
df["text_length"].mean()
# Out:
# 277.225

# %% [markdown]
# ### Most frequent words

# %%
from collections import Counter
import re

all_text = " ".join(df["text"].tolist()).lower()
words = re.findall(r"\b[a-z]{4,}\b", all_text)

word_counts = Counter(words)
word_counts.most_common(20)
# Out:
# [('that', 86),
#  ('space', 54),
#  ('with', 42),
#  ('reuters', 40),
#  ('this', 38),
#  ('from', 34),
#  ('they', 34),
#  ('have', 33),
#  ('said', 29),
#  ('about', 23),
#  ('more', 23),
#  ('their', 19),
#  ('scientists', 19),
#  ('what', 19),
#  ('would', 19),
#  ('over', 18),
#  ('after', 18),
#  ('could', 18),
#  ('time', 17),
#  ('company', 17)]

# %% [markdown]
# ## Reflection
#
# Are we predicting something here?
#
# Or are we discovering patterns already present in the data?

# %% [markdown]
# We discovering patterns already present in the data

# %% [markdown]
# # Part B — Machine Learning: Use labels

# %% [markdown]
# ### Inspect labels

# %%
df["label"].value_counts()
# Out:
# label
# 3    122
# 2     78
# Name: count, dtype: int64

# %% [markdown]
# ### AG News labels are numeric. Add names:
# from https://huggingface.co/datasets/sh0416/ag_news
#
# 1: World 2: Sports 3: Business 4: Sci/Tech

# %%
label_names = {
    0: "World",
    1: "Sports",
    2: "Business",
    3: "Sci/Tech"
}

df["label_name"] = df["label"].map(label_names)
df[["text", "label", "label_name"]].head()
# Out:
#                                                 text  label label_name
# 0  Wall St. Bears Claw Back Into the Black (Reute...      2   Business
# 1  Carlyle Looks Toward Commercial Aerospace (Reu...      2   Business
# 2  Oil and Economy Cloud Stocks' Outlook (Reuters...      2   Business
# 3  Iraq Halts Oil Exports from Main Southern Pipe...      2   Business
# 4  Oil prices soar to all-time record, posing new...      2   Business

# %% [markdown]
# ## Question
#
# What type of ML can we apply for this dataset?

# %%
We can use Supervised learning because there are different labels

# %% [markdown]
# # Part C — Explore a Dataset

# %% [markdown]
# In this exercise, you will:
#
# 1. Choose a dataset
# 2. Explore it (Data Mining)
# 3. Decide whether labels exist
# 4. Suggest a Machine Learning approach (if applicable)
#
# You should NOT focus on complex models.
# Focus on understanding the problem.

# %% [markdown]
# ## Step 1 — Choose a dataset

# %% [markdown]
# * Hugging Face datasets: https://huggingface.co/datasets
# * Scikit-learn datasets: https://scikit-learn.org/stable/datasets/toy_dataset.html

# %% [markdown]
# Dataset examples:

# %%
from datasets import load_dataset
dataset = load_dataset("beans", split="train[:100]")

df = dataset.to_pandas()
df.head()

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Get one example
example = dataset[0]

# Load image
image = example["image"]

# Display
plt.imshow(image)
plt.title(f"Label: {example['labels']}")
plt.axis("off")
plt.show()

# %%
from datasets import load_dataset

dataset = load_dataset("timm/oxford-iiit-pet", split="train[:100]")

df = dataset.to_pandas()
df.head()
# Out:
# README.md: 0.00B [00:00, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# data/train-00000-of-00001.parquet:   0%|          | 0.00/378M [00:00<?, ?B/s]
# Cancellation requested; stopping current tasks.
#
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/myenv/lib/python3.11/site-packages/stack_data/core.py:597, in FrameInfo.stack_data(cls, frame_or_tb, options, collapse_repeated_frames)
#     594     frame, lineno = frame_and_lineno(x)
#     595     return frame.f_code, lineno
# --> 597 yield from collapse_repeated(
#     598     stack,
#     599     mapper=mapper,
#     600     collapser=RepeatedFrames,
#     601     key=_frame_key,
#     602 )
#
# File ~/myenv/lib/python3.11/site-packages/stack_data/utils.py:83, in collapse_repeated(lst, collapser, mapper, key)
#      81 original_group, highlighted_group = zip(*group)
#      82 if is_highlighted:
# ---> 83     yield from map(mapper, original_group)
#      84 else:
#      85     keyed_group, _ = zip(*highlighted_group)
#
# File ~/myenv/lib/python3.11/site-packages/stack_data/core.py:587, in FrameInfo.stack_data.<locals>.mapper(f)
#     586 def mapper(f):
# --> 587     return cls(f, options)
#
# File ~/myenv/lib/python3.11/site-packages/stack_data/core.py:551, in FrameInfo.__init__(self, frame_or_tb, options)
#     546 def __init__(
#     547         self,
#     548         frame_or_tb: Union[FrameType, TracebackType],
#     549         options: Optional[Options] = None,
#     550 ):
# --> 551     self.executing = Source.executing(frame_or_tb)
#     552     frame, self.lineno = frame_and_lineno(frame_or_tb)
#     553     self.frame = frame
#
# File ~/myenv/lib/python3.11/site-packages/executing/executing.py:224, in Source.executing(cls, frame_or_tb)
#     222 if not args:
#     223     node = stmts = decorator = None
# --> 224     source = cls.for_frame(frame)
#     225     tree = source.tree
#     226     if tree:
#
# File ~/myenv/lib/python3.11/site-packages/executing/executing.py:143, in Source.for_frame(cls, frame, use_cache)
#     137 @classmethod
#     138 def for_frame(cls, frame, use_cache=True):
#     139     # type: (types.FrameType, bool) -> "Source"
#     140     """
#     141     Returns the `Source` object corresponding to the file the frame is executing in.
#     142     """
# --> 143     return cls.for_filename(frame.f_code.co_filename, frame.f_globals or {}, use_cache)
#
# File ~/myenv/lib/python3.11/site-packages/executing/executing.py:172, in Source.for_filename(cls, filename, module_globals, use_cache)
#     169     linecache.cache[filename] = entry # type: ignore[attr-defined]
#     170     lines = get_lines()
# --> 172 return cls._for_filename_and_lines(filename, tuple(lines))
#
# File ~/myenv/lib/python3.11/site-packages/executing/executing.py:183, in Source._for_filename_and_lines(cls, filename, lines)
#     180 except KeyError:
#     181     pass
# --> 183 result = source_cache[(filename, lines)] = cls(filename, lines)
#     184 return result
#
# File ~/myenv/lib/python3.11/site-packages/executing/executing.py:123, in Source.__init__(self, filename, lines)
#     120 self._asttext = None  # type: Optional[ASTText]
#     122 try:
# --> 123     self.tree = ast.parse(self.text, filename=filename)
#     124 except (SyntaxError, ValueError):
#     125     pass
#
# File /usr/local/Cellar/python@3.11/3.11.15_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ast.py:50, in parse(source, filename, mode, type_comments, feature_version)
#      48     feature_version = -1
#      49 # Else it should be an int giving the minor version for 3.x.
# ---> 50 return compile(source, filename, mode, flags,
#      51                _feature_version=feature_version)
#
# KeyboardInterrupt:

# %%
# Get one example
example = dataset[1]

# Load image
image = example["image"]

# Display
plt.imshow(image)
# plt.title(f"Label: {example['labels']}")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Get one example
# ----> 2 example = dataset[1]
#       3
#       4 # Load image
#       5 image = example["image"]
#
# NameError: name 'dataset' is not defined

# %%
from sklearn.datasets import load_wine
import pandas as pd

data = load_wine()

df = pd.DataFrame(data.data, columns=data.feature_names)
df["label"] = data.target
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  label
# 0                          3.92   1065.0      0
# 1                          3.40   1050.0      0
# 2                          3.17   1185.0      0
# 3                          3.45   1480.0      0
# 4                          2.93    735.0      0

# %%
dataset = load_dataset("superb", "ks", split="train[:10]")

df = dataset.to_pandas()
df.head()
# Out:
#                                                 file  \
# 0  /root/.cache/huggingface/datasets/downloads/ex...
# 1  /root/.cache/huggingface/datasets/downloads/ex...
# 2  /root/.cache/huggingface/datasets/downloads/ex...
# 3  /root/.cache/huggingface/datasets/downloads/ex...
# 4  /root/.cache/huggingface/datasets/downloads/ex...
#
#                                                audio  label
# 0  {'bytes': b'RIFFXz.\x00WAVEfmt \x10\x00\x00\x0...     10
# 1  {'bytes': b'RIFF*.\x1e\x00WAVEfmt \x10\x00\x00...     10
# 2  {'bytes': b'RIFF0\xe9\x1d\x00WAVEfmt \x10\x00\...     10
# 3  {'bytes': b'RIFF$L\x1d\x00WAVEfmt \x10\x00\x00...     10
# 4  {'bytes': b'RIFF\xe4\xdc\x1d\x00WAVEfmt \x10\x...     10

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({
    "age": np.random.randint(18, 70, 50),
    "income": np.random.randint(1000, 5000, 50),
    "spending": np.random.randint(100, 2000, 50)
})

df.head()
# Out:
#    age  income  spending
# 0   20    2172       857
# 1   56    4569      1376
# 2   36    4161      1195
# 3   48    2529       896
# 4   23    1930       414

# %%
from datasets import load_dataset

dataset = load_dataset("Salesforce/wikitext", "wikitext-2-raw-v1", split="train[:200]")
df = dataset.to_pandas()
df.head()
# Out:
# README.md: 0.00B [00:00, ?B/s]
# wikitext-2-raw-v1/test-00000-of-00001.pa(…):   0%|          | 0.00/733k [00:00<?, ?B/s]
# wikitext-2-raw-v1/train-00000-of-00001.p(…):   0%|          | 0.00/6.36M [00:00<?, ?B/s]
# wikitext-2-raw-v1/validation-00000-of-00(…):   0%|          | 0.00/657k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/4358 [00:00<?, ? examples/s]
# Generating train split:   0%|          | 0/36718 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/3760 [00:00<?, ? examples/s]
#                                                 text
# 0
# 1                     = Valkyria Chronicles III = \n
# 2
# 3   Senjō no Valkyria 3 : Unrecorded Chronicles (...
# 4   The game began development in 2010 , carrying...

# %%
from datasets import load_dataset

dataset = load_dataset("tweet_eval", "sentiment", split="train[:200]")
df = dataset.to_pandas()

df.head()
# Out:
# README.md: 0.00B [00:00, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 from datasets import load_dataset
#       2
# ----> 3 dataset = load_dataset("tweet_eval", "sentiment", split="train[:200]")
#       4 df = dataset.to_pandas()
#       5
#       6 df.head()
#
# File ~/myenv/lib/python3.11/site-packages/datasets/load.py:1688, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1683 verification_mode = VerificationMode(
#    1684     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    1685 )
#    1687 # Create a dataset builder
# -> 1688 builder_instance = load_dataset_builder(
#    1689     path=path,
#    1690     name=name,
#    1691     data_dir=data_dir,
#    1692     data_files=data_files,
#    1693     cache_dir=cache_dir,
#    1694     features=features,
#    1695     download_config=download_config,
#    1696     download_mode=download_mode,
#    1697     revision=revision,
#    1698     token=token,
#    1699     storage_options=storage_options,
#    1700     **config_kwargs,
#    1701 )
#    1703 # Return iterable dataset in case of streaming
#    1704 if streaming:
#
# File ~/myenv/lib/python3.11/site-packages/datasets/load.py:1315, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, **config_kwargs)
#    1313 if features is not None:
#    1314     features = _fix_for_backward_compatible_features(features)
# -> 1315 dataset_module = dataset_module_factory(
#    1316     path,
#    1317     revision=revision,
#    1318     download_config=download_config,
#    1319     download_mode=download_mode,
#    1320     data_dir=data_dir,
#    1321     data_files=data_files,
#    1322     cache_dir=cache_dir,
#    1323 )
#    1324 # Get dataset builder class
#    1325 builder_kwargs = dataset_module.builder_kwargs
#
# File ~/myenv/lib/python3.11/site-packages/datasets/load.py:1182, in dataset_module_factory(path, revision, download_config, download_mode, data_dir, data_files, cache_dir, **download_kwargs)
#    1172     else:
#    1173         use_exported_dataset_infos = True
#    1174     return HubDatasetModuleFactory(
#    1175         path,
#    1176         commit_hash=commit_hash,
#    1177         data_dir=data_dir,
#    1178         data_files=data_files,
#    1179         download_config=download_config,
#    1180         download_mode=download_mode,
#    1181         use_exported_dataset_infos=use_exported_dataset_infos,
# -> 1182     ).get_module()
#    1183 except GatedRepoError as e:
#    1184     message = f"Dataset '{path}' is a gated dataset on the Hub."
#
# File ~/myenv/lib/python3.11/site-packages/datasets/load.py:615, in HubDatasetModuleFactory.get_module(self)
#     613 if config.USE_PARQUET_EXPORT and self.use_exported_dataset_infos:
#     614     try:
# --> 615         exported_dataset_infos = _dataset_viewer.get_exported_dataset_infos(
#     616             dataset=self.name, commit_hash=self.commit_hash, token=self.download_config.token
#     617         )
#     618         exported_dataset_infos = DatasetInfosDict(
#     619             {
#     620                 config_name: DatasetInfo.from_dict(exported_dataset_infos[config_name])
#     621                 for config_name in exported_dataset_infos
#     622             }
#     623         )
#     624     except _dataset_viewer.DatasetViewerError:
#
# File ~/myenv/lib/python3.11/site-packages/datasets/utils/_dataset_viewer.py:71, in get_exported_dataset_infos(dataset, commit_hash, token)
#      69 dataset_viewer_info_url = config.HF_ENDPOINT.replace("://", "://datasets-server.") + "/info?dataset="
#      70 try:
# ---> 71     info_response = get_session().get(
#      72         url=dataset_viewer_info_url + dataset,
#      73         headers=get_authentication_headers_for_url(config.HF_ENDPOINT + f"datasets/{dataset}", token=token),
#      74         timeout=100.0,
#      75     )
#      76     info_response.raise_for_status()
#      77     if "X-Revision" in info_response.headers:
#
# File ~/myenv/lib/python3.11/site-packages/httpx/_client.py:1053, in Client.get(self, url, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1036 def get(
#    1037     self,
#    1038     url: URL | str,
#    (...)   1046     extensions: RequestExtensions | None = None,
#    1047 ) -> Response:
#    1048     """
#    1049     Send a `GET` request.
#    1050
#    1051     **Parameters**: See `httpx.request`.
#    1052     """
# -> 1053     return self.request(
#    1054         "GET",
#    1055         url,
#    1056         params=params,
#    1057         headers=headers,
#    1058         cookies=cookies,
#    1059         auth=auth,
#    1060         follow_redirects=follow_redirects,
#    1061         timeout=timeout,
#    1062         extensions=extensions,
#    1063     )
#
# File ~/myenv/lib/python3.11/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/myenv/lib/python3.11/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/myenv/lib/python3.11/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/myenv/lib/python3.11/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/myenv/lib/python3.11/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/myenv/lib/python3.11/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/myenv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/myenv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/myenv/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/myenv/lib/python3.11/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/myenv/lib/python3.11/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/myenv/lib/python3.11/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/myenv/lib/python3.11/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/myenv/lib/python3.11/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /usr/local/Cellar/python@3.11/3.11.15_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1295, in SSLSocket.recv(self, buflen, flags)
#    1291     if flags != 0:
#    1292         raise ValueError(
#    1293             "non-zero flags not allowed in calls to recv() on %s" %
#    1294             self.__class__)
# -> 1295     return self.read(buflen)
#    1296 else:
#    1297     return super().recv(buflen, flags)
#
# File /usr/local/Cellar/python@3.11/3.11.15_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1168, in SSLSocket.read(self, len, buffer)
#    1166         return self._sslobj.read(len, buffer)
#    1167     else:
# -> 1168         return self._sslobj.read(len)
#    1169 except SSLError as x:
#    1170     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Step 2 — Explore (Data Mining)

# %% [markdown]
# TODO 1: Display a few examples
#
# TODO 2: What type of data is this?
# (text, image, tabular)
#
# TODO 3: Find simple patterns
#
# Examples:
# - text: most frequent words
# - tabular: average values
# - images: visualize samples
# etc.

# %% [markdown]
# ## Step 3 — Think about labels

# %% [markdown]
# ### Questions
#
# 1. Does this dataset contain labels?
# 2. If yes:
#    - What are they?
# 3. If no:
#    - What could we try to discover?

# %% [markdown]
# ## Step 4 — Decide the type of ML

# %% [markdown]
# ### Identify the problem
#
# - Is this:
#   - Data Mining?
#   - Supervised Learning?
#   - Unsupervised Learning?
#   - Reinforcement Learning?
#
# Explain your reasoning.

# %% [markdown]
# ## Step 5 — Suggest a task

# %% [markdown]
# ### Your task
#
# Propose ONE task:
#
# - What is the input (X)?
# - What is the output (y)? (if any)
# - What is the goal?
#
# Examples:
# - classify articles
# - cluster customers
# - extract entities

# %%
from sklearn.datasets import load_wine
import pandas as pd

data = load_wine()

df = pd.DataFrame(data.data, columns=data.feature_names)
df["label"] = data.target
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  label
# 0                          3.92   1065.0      0
# 1                          3.40   1050.0      0
# 2                          3.17   1185.0      0
# 3                          3.45   1480.0      0
# 4                          2.93    735.0      0

# %%
Input: The load_wine() dataset from scikit-learn — a built-in dataset 
with 178 wine samples and 13 chemical features (alcohol, malic_acid, 
ash, etc.) plus a target label (wine class 0, 1, or 2).

# %%
Output: A pandas DataFrame showing the first 5 rows (df.head()), with:
- Columns: the 13 chemical feature names (alcohol, malic_acid, ash, ...)
- Rows (index 0–4): the first 5 wine samples with their measured values
- Label column: the wine class

# %%
Goal: 
- Load the Wine dataset (178 wine samples with 13 chemical measurements)
- Convert it to a pandas DataFrame for easy viewing and manipulation
- Preview the first 5 rows to understand the structure of the data
